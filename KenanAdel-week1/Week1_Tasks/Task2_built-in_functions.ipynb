# %%
import difflib
print(difflib.get_close_matches("appel", ["apple", "ape", "peach"])) # تبحث عن الكلمات المتشابهة
# Out:
# ['apple', 'ape']

# %%
import webbrowser
webbrowser.open("https://google.com") #تسمح لك بفتح أي رابط إنترنت أو موقع مباشرة من داخل الكود

# %%
import secrets
print(secrets.token_hex(8)) # مخصصة لتوليد أرقام عشوائية ونصوص قوية جداً يصعب اختراقها

# %%
import uuid
print(uuid.uuid4()) # تقوم بإنشاء "رقم معرف"  فريد جداً وعالمي

# %%
import shutil
shutil.copy("source.txt", "destination.txt") #تعطيك قوة كبيرة للتعامل مع الملفات، مثل نسخ مجلد كامل بجميع محتوياته، أو نقله، أو حتى حذفه بالكامل

# %%
import calendar
print(calendar.month(2026, 2)) # تولد لك تقويماً كاملاً ومرتباً لأي شهر أو سنة وتطبعه لك بشكل جاهز في شاشة الأوامر

# %%
from collections import Counter
votes = ['Kenan', 'Omar', 'Kenan', 'Sara', 'Omar', 'Kenan']
print(Counter(votes)) # قوم بعد العناصر المتكررة في قائمة فوراً
# Out:
# Counter({'Ali': 3, 'Omar': 2, 'Sara': 1})

# %%
import statistics
grades = [90, 85, 92, 70, 88]
print(statistics.mean(grades)) # تغنيك عن كتابة معادلات طويلة لحساب المتوسط، الوسيط
